# %%
import pandas as pd
import numpy as np
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}

# %%
print("Original data")
pd.DataFrame(data)
# Out:
# Original data
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
#remove rows with missing values
df = pd.DataFrame(data)
df = df.dropna()
print("\nData after removing rows with missing values:")
print(df)
# Out:
# Data after removing rows with missing values:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
#impute missing val with the mean

ec_mean=df["Energy Consumption (MWh)"].mean()
print("Mean of energy consumption(Mwh)",ec_mean)
cost_mean=df["Cost (Million $)"].mean()
print("Mean of cost (Million $)", cost_mean)
# Out:
# Mean of energy consumption(Mwh) 1850.0
# Mean of cost (Million $) 225.0

# %%
forward_filled_df = df.fillna(method="ffill")
print("\nData after forward-filling missing values:")
print(forward_filled_df)
# Out:
# Data after forward-filling missing values:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0
# <ipython-input-12-1f1212e0ec20>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_filled_df = df.fillna(method="ffill")

# %%
#forward fill method for missing values
# Create a DataFrame called data_df from the 'data' dictionary
data_df = pd.DataFrame(data)
forward_fill = data_df.fillna(method="ffill")
print("Data before forward fill:")
print(data_df)
print("\nData after forward fill:")
forward_fill.head()
# Out:
# Data before forward fill:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
#
# Data after forward fill:
# <ipython-input-13-14608496d071>:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_fill = data_df.fillna(method="ffill")
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    1200.0             400.0
# 2    Hydropower                    2900.0             400.0
# 3    Geothermal                    2900.0             150.0
# 4       Biomass                    2500.0             250.0

# %%
# Create a flag column indicating missing values in 'Energy Consumption (MWh)'
df["Missing Consumption"] = energy_df["Energy Consumption (MWh)"].isna().astype(int)
df["Missing Cost"] = energy_df["Cost (Million $)"].isna().astype(int)

print("\nData with Missing Values Flagged:")
df.head()
# Out:
# Data with Missing Values Flagged:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)  \
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0
#
#    Missing Consumption  Missing Cost
# 0                    0             0
# 4                    0             0

# %%
# Create a DataFrame called energy_df from the 'data' dictionary
energy_df = pd.DataFrame(data)

# Create a flag column indicating missing values in 'Energy Consumption (MWh)'
energy_df["Missing Consumption"] = energy_df["Energy Consumption (MWh)"].isna().astype(int)
energy_df["Missing Cost"] = energy_df["Cost (Million $)"].isna().astype(int)

print("\nData with Missing Values Flagged:")
energy_df.head()
# Out:
# Data with Missing Values Flagged:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)  \
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
#
#    Missing Consumption  Missing Cost
# 0                    0             0
# 1                    1             0
# 2                    0             1
# 3                    1             0
# 4                    0             0

# %%
#we will scale the data to a range between 0 and 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
scaled_df = pd.DataFrame(scaled_data, columns=["Energy Consumption (MWh)", "Cost (Million $)"])
print("\nScaled Data:")
scaled_df.head()
# Out:
# Scaled Data:
#    Energy Consumption (MWh)  Cost (Million $)
# 0                      0.00               0.2
# 1                       NaN               1.0
# 2                      0.85               NaN
# 3                       NaN               0.0
# 4                      0.65               0.4

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
energy_df["Energy Consumption (MWh)"] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)"]])
# Corrected the column names in the selection
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]]

print("\nData after Min-Max Scaling:")
print(energy_df)
#energy_df.head()
# Out:
# Data after Min-Max Scaling:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)  \
# 0         Solar                      0.00             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                      0.85               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                      0.65             250.0
# 5       Nuclear                      1.00               NaN
#
#    Missing Consumption  Missing Cost
# 0                    0             0
# 1                    1             0
# 2                    0             1
# 3                    1             0
# 4                    0             0
# 5                    0             1

# %%
#standardization
#Z-Score Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print("\nData after Z-Score Scaling:")
print(energy_df)
# Out:
# Data after Z-Score Scaling:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)  \
# 0         Solar                 -1.637804         -0.534522
# 1          Wind                       NaN          1.603567
# 2    Hydropower                  0.589610               NaN
# 3    Geothermal                       NaN         -1.069045
# 4       Biomass                  0.065512          0.000000
# 5       Nuclear                  0.982683               NaN
#
#    Missing Consumption  Missing Cost
# 0                    0             0
# 1                    1             0
# 2                    0             1
# 3                    1             0
# 4                    0             0
# 5                    0             1

# %%
#label encoding
energy_encoded_df = pd.get_dummies(energy_df, columns=["Energy Source"])
print("\nData after Label Encoding:")
energy_encoded_df.head()
#print(energy_encoded_df)
# Out:
# Data after Label Encoding:
#    Energy Consumption (MWh)  Cost (Million $)  Missing Consumption  \
# 0                 -1.637804         -0.534522                    0
# 1                       NaN          1.603567                    1
# 2                  0.589610               NaN                    0
# 3                       NaN         -1.069045                    1
# 4                  0.065512          0.000000                    0
#
#    Missing Cost  Energy Source_Biomass  Energy Source_Geothermal  \
# 0             0                  False                     False
# 1             0                  False                     False
# 2             1                  False                     False
# 3             0                  False                      True
# 4             0                   True                     False
#
#    Energy Source_Hydropower  Energy Source_Nuclear  Energy Source_Solar  \
# 0                     False                  False                 True
# 1                     False                  False                False
# 2                      True                  False                False
# 3                     False                  False                False
# 4                     False                  False                False
#
#    Energy Source_Wind
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False

# %%
# One-hot encode the 'Energy Source' column
energy_encoded_df = pd.get_dummies(energy_df, columns=["Energy Source"])
